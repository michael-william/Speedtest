# %%
# Data manipulation
import pandas as pd
import numpy as np
from datetime import datetime

# Display all cell outputs
#from IPython.core.interactiveshell import InteractiveShell
#InteractiveShell.ast_node_interactivity = 'all'

#from IPython import get_ipython
#ipython = get_ipython()

# autoreload extension
#if 'autoreload' not in ipython.extension_manager.loaded:
 #   %load_ext autoreload

#%autoreload 2

# Visualizations
from matplotlib import pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
#import plotly.figure_factory as ff
import plotly.io as pio
import plotly.offline as pyo
pio.renderers.default = 'iframe'
from ipywidgets import widgets

# %%
df = pd.read_csv('https://github.com/michael-william/Speedtest/raw/master/speedtest_logs.csv', parse_dates=[3,4])
df.rename(columns={'time':'hour'}, inplace=True)
#df['time'] = pd.to_datetime(df.time, format='%H:%M:%S')
#df['time'] = [time.time() for time in df['time']]
df['hour'] = df.hour.dt.round('H').dt.hour
df['week'] = df.date.dt.week
df['month'] = df.date.dt.month

# %%
df
# Out:
#       ping  download  upload       date  hour  week  month
# 0    12.71    201.34   22.27 2020-07-04    14    27      7
# 1    14.29     83.66   21.81 2020-07-04    15    27      7
# 2    14.03    265.05   30.50 2020-07-04    15    27      7
# 3    11.48    146.27   23.02 2020-07-04    15    27      7
# 4    13.72    111.09   30.61 2020-07-04    15    27      7
# ..     ...       ...     ...        ...   ...   ...    ...
# 166  15.98    179.71   14.74 2020-07-22     8    30      7
# 167  17.36    124.40    5.11 2020-07-22     9    30      7
# 168  17.17    114.98    6.34 2020-07-22    10    30      7
# 169  15.39    128.86   15.35 2020-07-23    10    30      7
# 170  14.70     98.74    7.44 2020-07-23    11    30      7
#
# [171 rows x 7 columns]

# %%
def SetColor(x):
        if(x < 100):
            return "orange"
        elif(100<= x <=200):
            return "white"
        elif(x > 200):
            return "black"

ping = go.Bar(
    x=df['hour'],
    y=df['ping'],
    opacity = 0.75,
    hoverinfo="name + y",
    name='Ping(ms)')

down = go.Bar(
    x=df['hour'],
    y=df['download'],
    opacity = 0.75,
    hoverinfo="name + y",
    name='Download (mbs)')

up = go.Bar(
    x=df['hour'],
    y=df['upload'],
    opacity = 0.75,
    hoverinfo="name + y",
    name = 'Upload (mbs)')

data = [down, up, ping]

layout = go.Layout(
    title='WiFi Stats',
    barmode='overlay', 
    hovermode='y')

fig = go.Figure(data=data, layout=layout)
fig.update_layout(hovermode='closest')
#pyo.plot(fig, filename='Wifi_Stats.html')
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_127.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
